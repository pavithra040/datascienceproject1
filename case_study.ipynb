# %% [markdown]
# <a href="https://colab.research.google.com/github/pavithra040/datascienceproject1/blob/main/case_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
path="/content/drive/MyDrive/energy.csv"
elecricity=pd.read_csv(path)
print(elecricity)
print(elecricity.shape)
print(elecricity.head(5))
print(elecricity.tail(4))
print(elecricity.info())
print(elecricity.describe())
print("column Data")
print(elecricity[elecricity['State'].str.startswith('M')])
print(elecricity[elecricity['State'].str.endswith('a')])
rcb=elecricity[elecricity['State']=='Andhra']
print(len(rcb))
rcb=elecricity[elecricity['State']=='Manipur']
print(len(rcb))
print(elecricity.sort_values(by='State'))
print(np.max(elecricity['Consumption']))
print(np.min(elecricity['Consumption']))
print(np.median(elecricity['Consumption']))
print(np.std(elecricity['Consumption']))
state1_data=elecricity[elecricity['State']=='Andhra']
state2_data=elecricity[elecricity['State']=='karnataka']
state4_data=elecricity[elecricity['State']=='Telengana']
state5_data=elecricity[elecricity['State']=='Tripura']
fig,axes=plt.subplots(2)
axes[0].plot(state1_data['Date'],state1_data['Consumption'],marker='*',color='red')
axes[1].plot(state1_data['Date'],state1_data['Consumption'],marker='*',color='green')
plt.show()
# Out:
#           Date        State  Consumption
# 0   01-01-2024    Tamilnadu       347.25
# 1   02-01-2024      Manipur       605.12
# 2   03-01-2024    Telengana       444.63
# 3   04-01-2024  Pondicherry       974.54
# 4   05-01-2024    Tamilnadu       864.02
# ..         ...          ...          ...
# 95  05-04-2024       Kerala       587.30
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
#
# [100 rows x 3 columns]
# (100, 3)
#          Date        State  Consumption
# 0  01-01-2024    Tamilnadu       347.25
# 1  02-01-2024      Manipur       605.12
# 2  03-01-2024    Telengana       444.63
# 3  04-01-2024  Pondicherry       974.54
# 4  05-01-2024    Tamilnadu       864.02
#           Date        State  Consumption
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# ...
